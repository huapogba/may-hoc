# %%
import cv2  
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import csv
import random
import torch
import torch.nn as nn
import torchvision.models as models

# %%
def preprocess_image(
    image,
    output_size=(28, 28),
    margin=5,
    median_kernel_size=5,
    adaptive_block_size=17,
    adaptive_C=5
):
    # Apply Median Filter to reduce salt-and-pepper noise
    if median_kernel_size % 2 == 0 or median_kernel_size < 1:
        print(f"Warning: median_kernel_size must be a positive odd integer. Using default of 3.")
        median_kernel_size = 3
    gray_filtered = cv2.medianBlur(image, median_kernel_size)

    # Apply adaptive thresholding on the filtered image
    if adaptive_block_size % 2 == 0:
        # print(f"Warning: adaptive_block_size must be odd. Adjusting {adaptive_block_size} to {adaptive_block_size + 1}")
        adaptive_block_size +=1
    
    binary = cv2.adaptiveThreshold(gray_filtered, 255, # Use gray_filtered here
                                    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                    cv2.THRESH_BINARY_INV,
                                    adaptive_block_size, adaptive_C)

    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        print(f"Warning: No contours found in image after filtering and adaptive thresholding. Skipping.")
        return None

    cnt = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(cnt)

    original_h_binary, original_w_binary = binary.shape[:2]

    x_margin = max(0, x - margin)
    y_margin = max(0, y - margin)
    w_margin = min(original_w_binary - x_margin, w + 2 * margin)
    h_margin = min(original_h_binary - y_margin, h + 2 * margin)
    
    if w_margin <= 0 or h_margin <= 0:
        print(f"Warning: Margin calculation resulted in non-positive dimension for image. Using original bounding box.")
        dig = binary[y:y+h, x:x+w]
    else:
        dig = binary[y_margin:y_margin+h_margin, x_margin:x_margin+w_margin]

    if dig.size == 0:
        print(f"Warning: Cropping with margin resulted in empty image for image. Skipping.")
        return None
    
    (dh, dw) = dig.shape[:2]
    size_max = max(dw, dh)
    square = np.zeros((size_max, size_max), dtype=np.uint8)

    x_offset = (size_max - dw) // 2
    y_offset = (size_max - dh) // 2
    square[y_offset:y_offset+dh, x_offset:x_offset+dw] = dig

    final_image = cv2.resize(square, output_size, interpolation=cv2.INTER_AREA)

    return final_image

def preprocess_images(
    input_path,
):
    images = []
    labels = []
    for digit_class in range(10):
        image_paths = list(Path(input_path).rglob(f"{digit_class}/*"))
        for image_path in image_paths:
            gray_img = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
            if gray_img is None:
                print(f"Warning: Could not read image {image_path}. Skipping.")
                continue
            final_image = preprocess_image(gray_img)
            if final_image is None:
                continue
            images.append(final_image)
            labels.append(digit_class)

    return images, labels

# %%
images, labels = preprocess_images('./dataset')

# %%
def display_sample_images(images, labels, label):
    plt.figure(figsize=(6, 20))
    j = 0
    for i in range(len(images)):
        if labels[i] != label:
            continue
        plt.subplot(20, 6, j + 1)  # Create a grid with 2 rows and 5 columns
        plt.imshow(images[i], cmap="gray")  # Display the image in grayscale
        plt.axis("off")  # Turn off the axis for cleaner visualization
        j += 1
        if j >= 120:
            break
    
    plt.tight_layout()
    plt.show()

# %%
display_sample_images(images, labels, label=1)

# %%
# --- Configuration ---
MODEL_PATH = 'adapted_resnet_digit_classifier.pth' # Path where you saved your model weights
RESNET_VARIANT = 'resnet34' # Must match the variant you trained (e.g., 'resnet18' or 'resnet34')
NUM_CLASSES = 10


# --- Define Modified ResNet18 (or ResNet34) ---
class AdaptedResNet(nn.Module):
    def __init__(self, num_classes=10, resnet_variant='resnet18'):
        super().__init__()
        if resnet_variant == 'resnet18':
            self.resnet = models.resnet18(weights=None) # No pretrained weights, or use models.ResNet18_Weights.DEFAULT for latest
        elif resnet_variant == 'resnet34':
            self.resnet = models.resnet34(weights=None) # No pretrained weights, or use models.ResNet34_Weights.DEFAULT
        else:
            raise ValueError("resnet_variant must be 'resnet18' or 'resnet34'")

        # 1. Modify the first convolutional layer for 1 input channel and 28x28 images
        # Original: self.resnet.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # Adapted: Use a smaller kernel, stride 1 to preserve dimensions initially
        self.resnet.conv1 = nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1, bias=False)

        # 2. Remove or modify the initial MaxPool layer
        # For 28x28, it's often better to remove it or make it identity
        self.resnet.maxpool = nn.Identity() # Effectively removes the max pooling

        # 3. Modify the final fully connected layer for 10 classes
        num_ftrs = self.resnet.fc.in_features
        self.resnet.fc = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.resnet(x)

# %%
# Assuming 'images_array' is your NumPy array of shape (num_samples, 28, 28)
# Assuming 'labels_array' is your NumPy array of shape (num_samples,)

# Convert NumPy arrays to PyTorch tensors
# Add channel dimension for grayscale: (num_samples, 1, 28, 28)
train_images = torch.tensor(images, dtype=torch.float32).unsqueeze(1)
train_labels = torch.tensor(labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
from torch.utils.data import TensorDataset, DataLoader
dataset = TensorDataset(train_images, train_labels)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True) # Adjust batch_size



# Instantiate the model
# model = AdaptedResNet(num_classes=10, resnet_variant='resnet18')
model = AdaptedResNet(num_classes=NUM_CLASSES, resnet_variant=RESNET_VARIANT) # Or resnet34

# Example: Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# --- Training Loop (Conceptual) ---
num_epochs = 10 # Adjust as needed

print(f"Starting training for {num_epochs} epochs...")
for epoch in range(num_epochs):
    model.train() # Set model to training mode
    running_loss = 0.0
    for i, (batch_images, batch_labels) in enumerate(dataloader):
        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(batch_images)
        loss = criterion(outputs, batch_labels)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if (i + 1) % 10 == 0: # Print statistics every 10 batches
            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{i+1}/{len(dataloader)}], Loss: {loss.item():.4f}")

    epoch_loss = running_loss / len(dataloader)
    print(f"Epoch [{epoch+1}/{num_epochs}] completed. Average Loss: {epoch_loss:.4f}")

print("Finished Training")

torch.save(model.state_dict(), MODEL_PATH)
print(f"Model state_dict saved to ${MODEL_PATH}")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


model = AdaptedResNet(num_classes=NUM_CLASSES, resnet_variant=RESNET_VARIANT)
try:
    model.load_state_dict(torch.load(MODEL_PATH, map_location=device)) # map_location ensures it loads correctly even if trained on GPU and inferring on CPU
    print(f"Model weights loaded successfully from {MODEL_PATH}")
except FileNotFoundError:
    print(f"ERROR: Model weights file not found at {MODEL_PATH}. Please ensure the path is correct.")
    exit()
except Exception as e:
    print(f"ERROR: Could not load model weights. Reason: {e}")
    exit()

model.to(device)

model.eval()
print("Model set to evaluation mode.")

csv_filename= 'resnet34.csv'
image_paths = list(Path("./testset").rglob("*"))

with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["filename", "predicted_label"])
    i = 1
    for image_path in image_paths:
        gray_img = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
        print(f"Processing image {i}")
        i += 1
        if gray_img is None:
            print(f"Warning: Could not read image {image_path}. Skipping.")
            writer.writerow([image_path.name, random.randint(0, 9)])  
            continue
        new_image_data_processed = preprocess_image(gray_img)
        if new_image_data_processed is None:
            new_image_data_processed = cv2.resize(gray_img, (28, 28), interpolation=cv2.INTER_AREA)

        input_tensor = torch.tensor(new_image_data_processed, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        input_tensor = input_tensor.to(device)

       
        with torch.no_grad():
            output_logits = model(input_tensor)

        probabilities = torch.softmax(output_logits, dim=1)
        confidence, predicted_class_index = torch.max(probabilities, 1)

        predicted_digit = predicted_class_index.item()

        writer.writerow([image_path.name, predicted_digit])

    print(f"Data successfully written to '{csv_filename}'")
# Out:
# Using device: cpu
# Model weights loaded successfully from adapted_resnet_digit_classifier.pth
# Model set to evaluation mode.
# Processing image 1
# Processing image 2
# Processing image 3
# Processing image 4
# Processing image 5
# Processing image 6
# Processing image 7
# Processing image 8
# Processing image 9
# Processing image 10
# Processing image 11
# Processing image 12
# Processing image 13
# Warning: Could not read image testset/004d39d8a48b484ba47ac058af0307d2.HEIC. Skipping.
# Processing image 14
# Processing image 15
# Processing image 16
# Processing image 17
# Processing image 18
# Processing image 19
# Processing image 20
# Processing image 21
# Processing image 22
# Processing image 23
# Processing image 24
# Processing image 25
# Processing image 26
# Processing image 27
# Processing image 28
# Processing image 29
# Processing image 30
# Processing image 31
# Processing image 32
# Processing image 33
# Processing image 34
# Processing image 35
# Processing image 36
# Processing image 37
# Processing image 38
# Processing image 39
# Processing image 40
# Processing image 41
# Processing image 42
# Processing image 43
# Processing image 44
# Processing image 45
# Processing image 46
# Processing image 47
# Processing image 48
# Processing image 49
# Processing image 50
# Processing image 51
# Processing image 52
# Warning: No contours found in image after filtering and adaptive thresholding. Skipping.
# Processing image 53
# Processing image 54
# Processing image 55
# Processing image 56
# Processing image 57
# Processing image 58
# Processing image 59
# Processing image 60
# Processing image 61
# Processing image 62
# Processing image 63
# Processing image 64
# Processing image 65
# Warning: Could not read image testset/34dff8cda52938e0ba5af071f116e88c.HEIC. Skipping.
# Processing image 66
# Processing image 67
# Processing image 68
# Processing image 69
# Processing image 70
# Processing image 71
# Processing image 72
# Processing image 73
# Processing image 74
# Processing image 75
# Processing image 76
# Processing image 77
# Processing image 78
# Processing image 79
# Processing image 80
# Processing image 81
# Processing image 82
# Processing image 83
# Processing image 84
# Processing image 85
# Processing image 86
# Processing image 87
# Processing image 88
# Processing image 89
# Processing image 90
# Processing image 91
# Processing image 92
# Processing image 93
# Processing image 94
# Processing image 95
# Processing image 96
# Processing image 97
# Processing image 98
# Processing image 99
# Processing image 100
# Processing image 101
# Processing image 102
# Processing image 103
# Processing image 104
# Processing image 105
# Processing image 106
# Processing image 107
# Processing image 108
# Processing image 109
# Processing image 110
# Processing image 111
# Processing image 112
# Processing image 113
# Processing image 114
# Processing image 115
# Processing image 116
# Processing image 117
# Warning: Could not read image testset/4f9b940f50aca0456b4b2cde2efac1e6.HEIC. Skipping.
# Processing image 118
# Processing image 119
# Processing image 120
# Processing image 121
# Processing image 122
# Processing image 123
# Processing image 124
# Processing image 125
# Processing image 126
# Processing image 127
# Processing image 128
# Processing image 129
# Processing image 130
# Processing image 131
# Processing image 132
# Processing image 133
# Processing image 134
# Processing image 135
# Processing image 136
# Processing image 137
# Processing image 138
# Processing image 139
# Processing image 140
# Processing image 141
# Processing image 142
# Processing image 143
# Processing image 144
# Processing image 145
# Processing image 146
# Processing image 147
# Processing image 148
# Processing image 149
# Processing image 150
# Processing image 151
# Processing image 152
# Processing image 153
# Processing image 154
# Processing image 155
# Processing image 156
# Processing image 157
# Processing image 158
# Processing image 159
# Processing image 160
# Processing image 161
# Processing image 162
# Processing image 163
# Processing image 164
# Processing image 165
# Processing image 166
# Processing image 167
# Processing image 168
# Processing image 169
# Processing image 170
# Processing image 171
# Processing image 172
# Processing image 173
# Processing image 174
# Processing image 175
# Processing image 176
# Processing image 177
# Processing image 178
# Processing image 179
# Processing image 180
# Processing image 181
# Processing image 182
# Processing image 183
# Processing image 184
# Processing image 185
# Processing image 186
# Processing image 187
# Processing image 188
# Processing image 189
# Processing image 190
# Processing image 191
# Processing image 192
# Processing image 193
# Processing image 194
# Processing image 195
# Processing image 196
# Processing image 197
# Processing image 198
# Processing image 199
# Processing image 200
# Processing image 201
# Processing image 202
# Processing image 203
# Processing image 204
# Processing image 205
# Processing image 206
# Processing image 207
# Processing image 208
# Processing image 209
# Processing image 210
# Processing image 211
# Processing image 212
# Processing image 213
# Processing image 214
# Processing image 215
# Processing image 216
# Processing image 217
# Processing image 218
# Processing image 219
# Processing image 220
# Processing image 221
# Processing image 222
# Processing image 223
# Processing image 224
# Processing image 225
# Processing image 226
# Processing image 227
# Processing image 228
# Processing image 229
# Processing image 230
# Processing image 231
# Processing image 232
# Processing image 233
# Processing image 234
# Processing image 235
# Processing image 236
# Processing image 237
# Processing image 238
# Processing image 239
# Processing image 240
# Processing image 241
# Processing image 242
# Processing image 243
# Processing image 244
# Processing image 245
# Processing image 246
# Processing image 247
# Processing image 248
# Processing image 249
# Processing image 250
# Processing image 251
# Processing image 252
# Processing image 253
# Processing image 254
# Processing image 255
# Processing image 256
# Processing image 257
# Processing image 258
# Processing image 259
# Processing image 260
# Processing image 261
# Processing image 262
# Processing image 263
# Processing image 264
# Processing image 265
# Processing image 266
# Processing image 267
# Processing image 268
# Processing image 269
# Processing image 270
# Processing image 271
# Processing image 272
# Processing image 273
# Processing image 274
# Processing image 275
# Warning: Could not read image testset/0805481419bb2b520b0f433f5cca66e1.HEIC. Skipping.
# Processing image 276
# Processing image 277
# Processing image 278
# Processing image 279
# Processing image 280
# Processing image 281
# Processing image 282
# Processing image 283
# Processing image 284
# Processing image 285
# Processing image 286
# Processing image 287
# Processing image 288
# Processing image 289
# Processing image 290
# Processing image 291
# Processing image 292
# Processing image 293
# Processing image 294
# Processing image 295
# Processing image 296
# Processing image 297
# Processing image 298
# Processing image 299
# Processing image 300
# Processing image 301
# Warning: Could not read image testset/44cdb9034171b588d1117a72b782022a.HEIC. Skipping.
# Processing image 302
# Processing image 303
# Processing image 304
# Processing image 305
# Processing image 306
# Processing image 307
# Processing image 308
# Processing image 309
# Processing image 310
# Processing image 311
# Processing image 312
# Processing image 313
# Processing image 314
# Processing image 315
# Processing image 316
# Processing image 317
# Processing image 318
# Processing image 319
# Processing image 320
# Processing image 321
# Processing image 322
# Processing image 323
# Processing image 324
# Processing image 325
# Processing image 326
# Processing image 327
# Processing image 328
# Processing image 329
# Processing image 330
# Processing image 331
# Processing image 332
# Processing image 333
# Processing image 334
# Processing image 335
# Processing image 336
# Processing image 337
# Processing image 338
# Processing image 339
# Processing image 340
# Processing image 341
# Processing image 342
# Processing image 343
# Processing image 344
# Processing image 345
# Processing image 346
# Processing image 347
# Processing image 348
# Processing image 349
# Processing image 350
# Processing image 351
# Processing image 352
# Processing image 353
# Processing image 354
# Processing image 355
# Processing image 356
# Processing image 357
# Processing image 358
# Processing image 359
# Warning: Could not read image testset/f8cd19f8c25a8a79d40e06ff706fd6a1.HEIC. Skipping.
# Processing image 360
# Warning: Could not read image testset/f8d3dbfe59b434c9176772f0978ee01e.HEIC. Skipping.
# Processing image 361
# Processing image 362
# Processing image 363
# Processing image 364
# Processing image 365
# Processing image 366
# Processing image 367
# Processing image 368
# Processing image 369
# Processing image 370
# Processing image 371
# Processing image 372
# Processing image 373
# Processing image 374
# Processing image 375
# Processing image 376
# Processing image 377
# Processing image 378
# Processing image 379
# Warning: Could not read image testset/dbb7bae06ac5acffe3c8912675c4bc14  -.md. Skipping.
# Processing image 380
# Processing image 381
# Processing image 382
# Processing image 383
# Processing image 384
# Processing image 385
# Processing image 386
# Processing image 387
# Processing image 388
# Processing image 389
# Processing image 390
# Processing image 391
# Processing image 392
# Processing image 393
# Processing image 394
# Processing image 395
# Processing image 396
# Processing image 397
# Processing image 398
# Processing image 399
# Processing image 400
# Processing image 401
# Processing image 402
# Processing image 403
# Processing image 404
# Processing image 405
# Processing image 406
# Processing image 407
# Processing image 408
# Processing image 409
# Processing image 410
# Processing image 411
# Processing image 412
# Processing image 413
# Processing image 414
# Processing image 415
# Processing image 416
# Processing image 417
# Processing image 418
# Processing image 419
# Processing image 420
# Processing image 421
# Processing image 422
# Processing image 423
# Processing image 424
# Processing image 425
# Processing image 426
# Processing image 427
# Processing image 428
# Processing image 429
# Processing image 430
# Processing image 431
# Processing image 432
# Processing image 433
# Processing image 434
# Processing image 435
# Processing image 436
# Processing image 437
# Processing image 438
# Processing image 439
# Processing image 440
# Processing image 441
# Processing image 442
# Processing image 443
# Processing image 444
# Processing image 445
# Processing image 446
# Processing image 447
# Processing image 448
# Processing image 449
# Processing image 450
# Processing image 451
# Processing image 452
# Processing image 453
# Processing image 454
# Processing image 455
# Processing image 456
# Processing image 457
# Processing image 458
# Processing image 459
# Processing image 460
# Processing image 461
# Processing image 462
# Processing image 463
# Processing image 464
# Processing image 465
# Processing image 466
# Processing image 467
# Processing image 468
# Processing image 469
# Processing image 470
# Processing image 471
# Processing image 472
# Processing image 473
# Processing image 474
# Processing image 475
# Processing image 476
# Processing image 477
# Processing image 478
# Processing image 479
# Processing image 480
# Processing image 481
# Processing image 482
# Processing image 483
# Processing image 484
# Processing image 485
# Processing image 486
# Processing image 487
# Processing image 488
# Processing image 489
# Processing image 490
# Processing image 491
# Processing image 492
# Processing image 493
# Processing image 494
# Processing image 495
# Processing image 496
# Processing image 497
# Processing image 498
# Processing image 499
# Processing image 500
# Processing image 501
# Processing image 502
# Processing image 503
# Processing image 504
# Processing image 505
# Processing image 506
# Processing image 507
# Processing image 508
# Processing image 509
# Processing image 510
# Processing image 511
# Processing image 512
# Processing image 513
# Processing image 514
# Processing image 515
# Processing image 516
# Processing image 517
# Processing image 518
# Processing image 519
# Processing image 520
# Processing image 521
# Processing image 522
# Processing image 523
# Processing image 524
# Processing image 525
# Processing image 526
# Processing image 527
# Processing image 528
# Processing image 529
# Processing image 530
# Processing image 531
# Processing image 532
# Processing image 533
# Processing image 534
# Processing image 535
# Processing image 536
# Processing image 537
# Processing image 538
# Processing image 539
# Processing image 540
# Processing image 541
# Processing image 542
# Processing image 543
# Processing image 544
# Processing image 545
# Processing image 546
# Processing image 547
# Processing image 548
# Processing image 549
# Processing image 550
# Processing image 551
# Processing image 552
# Processing image 553
# Processing image 554
# Processing image 555
# Processing image 556
# Processing image 557
# Processing image 558
# Processing image 559
# Processing image 560
# Processing image 561
# Processing image 562
# Processing image 563
# Processing image 564
# Processing image 565
# Processing image 566
# Processing image 567
# Processing image 568
# Processing image 569
# Processing image 570
# Processing image 571
# Processing image 572
# Processing image 573
# Processing image 574
# Processing image 575
# Processing image 576
# Processing image 577
# Processing image 578
# Processing image 579
# Processing image 580
# Processing image 581
# Processing image 582
# Processing image 583
# Processing image 584
# Processing image 585
# Processing image 586
# Processing image 587
# Processing image 588
# Processing image 589
# Processing image 590
# Processing image 591
# Processing image 592
# Processing image 593
# Processing image 594
# Processing image 595
# Processing image 596
# Processing image 597
# Processing image 598
# Processing image 599
# Processing image 600
# Warning: Could not read image testset/d01038195f9879d6118fd253d23e0470.HEIC. Skipping.
# Processing image 601
# Processing image 602
# Processing image 603
# Processing image 604
# Processing image 605
# Processing image 606
# Processing image 607
# Processing image 608
# Processing image 609
# Processing image 610
# Processing image 611
# Processing image 612
# Processing image 613
# Processing image 614
# Processing image 615
# Processing image 616
# Processing image 617
# Processing image 618
# Processing image 619
# Processing image 620
# Processing image 621
# Processing image 622
# Processing image 623
# Processing image 624
# Processing image 625
# Processing image 626
# Processing image 627
# Processing image 628
# Processing image 629
# Processing image 630
# Processing image 631
# Processing image 632
# Processing image 633
# Processing image 634
# Processing image 635
# Processing image 636
# Processing image 637
# Processing image 638
# Processing image 639
# Processing image 640
# Processing image 641
# Processing image 642
# Processing image 643
# Processing image 644
# Processing image 645
# Processing image 646
# Processing image 647
# Processing image 648
# Processing image 649
# Processing image 650
# Processing image 651
# Processing image 652
# Processing image 653
# Processing image 654
# Processing image 655
# Processing image 656
# Processing image 657
# Processing image 658
# Processing image 659
# Processing image 660
# Processing image 661
# Processing image 662
# Processing image 663
# Processing image 664
# Processing image 665
# Processing image 666
# Processing image 667
# Processing image 668
# Processing image 669
# Processing image 670
# Processing image 671
# Processing image 672
# Processing image 673
# Processing image 674
# Processing image 675
# Processing image 676
# Processing image 677
# Processing image 678
# Processing image 679
# Processing image 680
# Warning: Could not read image testset/9ff224036fcd320556163e4b2feb813a.HEIC. Skipping.
# Processing image 681
# Processing image 682
# Processing image 683
# Processing image 684
# Processing image 685
# Warning: Could not read image testset/a008f795ae8498751f2e5feeb0b73387.jpeg. Skipping.
# Processing image 686
# Processing image 687
# Processing image 688
# Processing image 689
# Processing image 690
# Processing image 691
# Processing image 692
# Processing image 693
# Processing image 694
# Processing image 695
# Processing image 696
# Warning: Could not read image testset/609ae93438959bff10e7b96f8c24f779.HEIC. Skipping.
# Processing image 697
# Processing image 698
# Processing image 699
# Processing image 700
# Processing image 701
# Processing image 702
# Processing image 703
# Processing image 704
# Processing image 705
# Processing image 706
# Processing image 707
# Processing image 708
# Warning: Could not read image testset/60e297f9b4795ffe3d287de602411e82.HEIC. Skipping.
# Processing image 709
# Processing image 710
# Processing image 711
# Processing image 712
# Processing image 713
# Processing image 714
# Processing image 715
# Processing image 716
# Processing image 717
# Processing image 718
# Processing image 719
# Processing image 720
# Processing image 721
# Processing image 722
# Processing image 723
# Processing image 724
# Processing image 725
# Processing image 726
# Processing image 727
# Processing image 728
# Processing image 729
# Processing image 730
# Processing image 731
# Processing image 732
# Processing image 733
# Processing image 734
# Processing image 735
# Processing image 736
# Processing image 737
# Processing image 738
# Processing image 739
# Processing image 740
# Processing image 741
# Processing image 742
# Processing image 743
# Processing image 744
# Processing image 745
# Processing image 746
# Processing image 747
# Processing image 748
# Processing image 749
# Processing image 750
# Processing image 751
# Processing image 752
# Processing image 753
# Processing image 754
# Processing image 755
# Processing image 756
# Processing image 757
# Processing image 758
# Processing image 759
# Processing image 760
# Processing image 761
# Processing image 762
# Processing image 763
# Processing image 764
# Processing image 765
# Processing image 766
# Processing image 767
# Processing image 768
# Processing image 769
# Processing image 770
# Processing image 771
# Processing image 772
# Processing image 773
# Warning: No contours found in image after filtering and adaptive thresholding. Skipping.
# Processing image 774
# Processing image 775
# Processing image 776
# Processing image 777
# Processing image 778
# Processing image 779
# Processing image 780
# Processing image 781
# Processing image 782
# Processing image 783
# Processing image 784
# Processing image 785
# Processing image 786
# Processing image 787
# Processing image 788
# Processing image 789
# Processing image 790
# Processing image 791
# Processing image 792
# Processing image 793
# Processing image 794
# Processing image 795
# Processing image 796
# Processing image 797
# Processing image 798
# Processing image 799
# Processing image 800
# Processing image 801
# Processing image 802
# Processing image 803
# Processing image 804
# Processing image 805
# Processing image 806
# Processing image 807
# Warning: Could not read image testset/8e4a38bd19c94970f342494bb01213d8  -.HEIC. Skipping.
# Processing image 808
# Processing image 809
# Processing image 810
# Processing image 811
# Processing image 812
# Processing image 813
# Processing image 814
# Processing image 815
# Processing image 816
# Processing image 817
# Processing image 818
# Processing image 819
# Processing image 820
# Processing image 821
# Processing image 822
# Processing image 823
# Processing image 824
# Processing image 825
# Processing image 826
# Processing image 827
# Processing image 828
# Processing image 829
# Processing image 830
# Processing image 831
# Processing image 832
# Processing image 833
# Processing image 834
# Processing image 835
# Processing image 836
# Processing image 837
# Processing image 838
# Processing image 839
# Processing image 840
# Processing image 841
# Processing image 842
# Processing image 843
# Processing image 844
# Processing image 845
# Processing image 846
# Processing image 847
# Processing image 848
# Processing image 849
# Processing image 850
# Processing image 851
# Processing image 852
# Processing image 853
# Processing image 854
# Processing image 855
# Processing image 856
# Processing image 857
# Processing image 858
# Processing image 859
# Processing image 860
# Processing image 861
# Processing image 862
# Processing image 863
# Processing image 864
# Processing image 865
# Processing image 866
# Processing image 867
# Processing image 868
# Processing image 869
# Processing image 870
# Processing image 871
# Processing image 872
# Processing image 873
# Processing image 874
# Processing image 875
# Processing image 876
# Processing image 877
# Processing image 878
# Processing image 879
# Processing image 880
# Warning: Could not read image testset/8177c77268d83ea964e8cb178188b52a.HEIC. Skipping.
# Processing image 881
# Processing image 882
# Processing image 883
# Processing image 884
# Processing image 885
# Processing image 886
# Processing image 887
# Processing image 888
# Processing image 889
# Warning: Could not read image testset/81b728654dded4e1be0b8d918d647cb3.HEIC. Skipping.
# Processing image 890
# Processing image 891
# Processing image 892
# Processing image 893
# Processing image 894
# Processing image 895
# Processing image 896
# Processing image 897
# Processing image 898
# Processing image 899
# Processing image 900
# Processing image 901
# Processing image 902
# Processing image 903
# Processing image 904
# Processing image 905
# Processing image 906
# Processing image 907
# Processing image 908
# Processing image 909
# Processing image 910
# Processing image 911
# Processing image 912
# Processing image 913
# Processing image 914
# Processing image 915
# Processing image 916
# Processing image 917
# Processing image 918
# Processing image 919
# Processing image 920
# Processing image 921
# Processing image 922
# Processing image 923
# Processing image 924
# Processing image 925
# Processing image 926
# Processing image 927
# Processing image 928
# Processing image 929
# Processing image 930
# Processing image 931
# Processing image 932
# Processing image 933
# Processing image 934
# Processing image 935
# Processing image 936
# Processing image 937
# Processing image 938
# Processing image 939
# Processing image 940
# Processing image 941
# Processing image 942
# Processing image 943
# Processing image 944
# Processing image 945
# Processing image 946
# Processing image 947
# Processing image 948
# Processing image 949
# Processing image 950
# Processing image 951
# Processing image 952
# Processing image 953
# Processing image 954
# Processing image 955
# Processing image 956
# Processing image 957
# Processing image 958
# Processing image 959
# Processing image 960
# Processing image 961
# Processing image 962
# Processing image 963
# Processing image 964
# Processing image 965
# Processing image 966
# Processing image 967
# Processing image 968
# Processing image 969
# Processing image 970
# Processing image 971
# Processing image 972
# Processing image 973
# Processing image 974
# Processing image 975
# Processing image 976
# Processing image 977
# Processing image 978
# Processing image 979
# Processing image 980
# Processing image 981
# Processing image 982
# Processing image 983
# Processing image 984
# Processing image 985
# Processing image 986
# Processing image 987
# Processing image 988
# Processing image 989
# Processing image 990
# Processing image 991
# Processing image 992
# Processing image 993
# Processing image 994
# Processing image 995
# Processing image 996
# Processing image 997
# Processing image 998
# Processing image 999
# Processing image 1000
# Processing image 1001
# Processing image 1002
# Processing image 1003
# Processing image 1004
# Processing image 1005
# Processing image 1006
# Processing image 1007
# Processing image 1008
# Processing image 1009
# Processing image 1010
# Processing image 1011
# Processing image 1012
# Processing image 1013
# Processing image 1014
# Processing image 1015
# Processing image 1016
# Processing image 1017
# Processing image 1018
# Processing image 1019
# Processing image 1020
# Processing image 1021
# Processing image 1022
# Processing image 1023
# Processing image 1024
# Processing image 1025
# Processing image 1026
# Processing image 1027
# Processing image 1028
# Processing image 1029
# Processing image 1030
# Processing image 1031
# Processing image 1032
# Processing image 1033
# Processing image 1034
# Processing image 1035
# Processing image 1036
# Processing image 1037
# Processing image 1038
# Processing image 1039
# Processing image 1040
# Processing image 1041
# Processing image 1042
# Processing image 1043
# Processing image 1044
# Processing image 1045
# Processing image 1046
# Processing image 1047
# Processing image 1048
# Processing image 1049
# Processing image 1050
# Processing image 1051
# Processing image 1052
# Processing image 1053
# Processing image 1054
# Processing image 1055
# Processing image 1056
# Processing image 1057
# Processing image 1058
# Processing image 1059
# Processing image 1060
# Processing image 1061
# Processing image 1062
# Processing image 1063
# Processing image 1064
# Processing image 1065
# Processing image 1066
# Processing image 1067
# Processing image 1068
# Processing image 1069
# Processing image 1070
# Processing image 1071
# Processing image 1072
# Processing image 1073
# Processing image 1074
# Processing image 1075
# Processing image 1076
# Processing image 1077
# Processing image 1078
# Processing image 1079
# Processing image 1080
# Processing image 1081
# Processing image 1082
# Processing image 1083
# Processing image 1084
# Processing image 1085
# Warning: Could not read image testset/f36e0a9c5b7bab3d8a83c61f60144bf6.HEIC. Skipping.
# Processing image 1086
# Processing image 1087
# Processing image 1088
# Processing image 1089
# Processing image 1090
# Processing image 1091
# Processing image 1092
# Processing image 1093
# Processing image 1094
# Processing image 1095
# Processing image 1096
# Processing image 1097
# Processing image 1098
# Processing image 1099
# Processing image 1100
# Processing image 1101
# Processing image 1102
# Processing image 1103
# Processing image 1104
# Processing image 1105
# Processing image 1106
# Processing image 1107
# Processing image 1108
# Processing image 1109
# Processing image 1110
# Processing image 1111
# Processing image 1112
# Processing image 1113
# Warning: Could not read image testset/cbc4dc5a5e02031c9970b4ffc5112be4  -.md. Skipping.
# Processing image 1114
# Processing image 1115
# Processing image 1116
# Processing image 1117
# Processing image 1118
# Processing image 1119
# Processing image 1120
# Processing image 1121
# Processing image 1122
# Processing image 1123
# Processing image 1124
# Processing image 1125
# Processing image 1126
# Processing image 1127
# Processing image 1128
# Processing image 1129
# Processing image 1130
# Processing image 1131
# Processing image 1132
# Processing image 1133
# Processing image 1134
# Processing image 1135
# Processing image 1136
# Processing image 1137
# Processing image 1138
# Processing image 1139
# Processing image 1140
# Processing image 1141
# Processing image 1142
# Processing image 1143
# Processing image 1144
# Processing image 1145
# Processing image 1146
# Processing image 1147
# Processing image 1148
# Processing image 1149
# Processing image 1150
# Processing image 1151
# Processing image 1152
# Processing image 1153
# Processing image 1154
# Processing image 1155
# Processing image 1156
# Processing image 1157
# Processing image 1158
# Processing image 1159
# Processing image 1160
# Processing image 1161
# Processing image 1162
# Processing image 1163
# Processing image 1164
# Processing image 1165
# Processing image 1166
# Processing image 1167
# Processing image 1168
# Processing image 1169
# Processing image 1170
# Processing image 1171
# Processing image 1172
# Processing image 1173
# Processing image 1174
# Processing image 1175
# Processing image 1176
# Processing image 1177
# Processing image 1178
# Processing image 1179
# Processing image 1180
# Processing image 1181
# Processing image 1182
# Processing image 1183
# Processing image 1184
# Processing image 1185
# Processing image 1186
# Processing image 1187
# Processing image 1188
# Processing image 1189
# Processing image 1190
# Processing image 1191
# Processing image 1192
# Processing image 1193
# Processing image 1194
# Processing image 1195
# Processing image 1196
# Processing image 1197
# Processing image 1198
# Processing image 1199
# Processing image 1200
# Processing image 1201
# Processing image 1202
# Processing image 1203
# Processing image 1204
# Processing image 1205
# Processing image 1206
# Processing image 1207
# Processing image 1208
# Processing image 1209
# Processing image 1210
# Processing image 1211
# Processing image 1212
# Processing image 1213
# Processing image 1214
# Processing image 1215
# Processing image 1216
# Processing image 1217
# Processing image 1218
# Processing image 1219
# Processing image 1220
# Processing image 1221
# Processing image 1222
# Processing image 1223
# Processing image 1224
# Processing image 1225
# Processing image 1226
# Processing image 1227
# Processing image 1228
# Processing image 1229
# Warning: Could not read image testset/285ad4e940ef9a0ccd936de1953f0239.HEIC. Skipping.
# Processing image 1230
# Processing image 1231
# Processing image 1232
# Processing image 1233
# Processing image 1234
# Processing image 1235
# Processing image 1236
# Processing image 1237
# Processing image 1238
# Processing image 1239
# Processing image 1240
# Processing image 1241
# Processing image 1242
# Processing image 1243
# Processing image 1244
# Processing image 1245
# Processing image 1246
# Processing image 1247
# Processing image 1248
# Processing image 1249
# Processing image 1250
# Processing image 1251
# Processing image 1252
# Processing image 1253
# Processing image 1254
# Processing image 1255
# Processing image 1256
# Processing image 1257
# Processing image 1258
# Processing image 1259
# Processing image 1260
# Processing image 1261
# Processing image 1262
# Processing image 1263
# Processing image 1264
# Processing image 1265
# Processing image 1266
# Processing image 1267
# Processing image 1268
# Processing image 1269
# Processing image 1270
# Processing image 1271
# Processing image 1272
# Processing image 1273
# Processing image 1274
# Processing image 1275
# Processing image 1276
# Processing image 1277
# Processing image 1278
# Processing image 1279
# Processing image 1280
# Processing image 1281
# Processing image 1282
# Processing image 1283
# Processing image 1284
# Processing image 1285
# Processing image 1286
# Processing image 1287
# Processing image 1288
# Processing image 1289
# Processing image 1290
# Processing image 1291
# Processing image 1292
# Processing image 1293
# Processing image 1294
# Processing image 1295
# Processing image 1296
# Processing image 1297
# Processing image 1298
# Processing image 1299
# Processing image 1300
# Processing image 1301
# Warning: Could not read image testset/7c70c7650c4d4827170ba054df8a7755.HEIC. Skipping.
# Processing image 1302
# Processing image 1303
# Processing image 1304
# Processing image 1305
# Processing image 1306
# Processing image 1307
# Processing image 1308
# Processing image 1309
# Processing image 1310
# Processing image 1311
# Processing image 1312
# Processing image 1313
# Processing image 1314
# Processing image 1315
# Processing image 1316
# Processing image 1317
# Processing image 1318
# Processing image 1319
# Processing image 1320
# Processing image 1321
# Processing image 1322
# Processing image 1323
# Processing image 1324
# Processing image 1325
# Processing image 1326
# Processing image 1327
# Processing image 1328
# Processing image 1329
# Processing image 1330
# Processing image 1331
# Processing image 1332
# Processing image 1333
# Processing image 1334
# Processing image 1335
# Processing image 1336
# Processing image 1337
# Processing image 1338
# Processing image 1339
# Processing image 1340
# Processing image 1341
# Processing image 1342
# Processing image 1343
# Processing image 1344
# Processing image 1345
# Processing image 1346
# Processing image 1347
# Processing image 1348
# Processing image 1349
# Processing image 1350
# Processing image 1351
# Processing image 1352
# Processing image 1353
# Processing image 1354
# Processing image 1355
# Processing image 1356
# Processing image 1357
# Processing image 1358
# Processing image 1359
# Processing image 1360
# Processing image 1361
# Processing image 1362
# Processing image 1363
# Processing image 1364
# Processing image 1365
# Processing image 1366
# Processing image 1367
# Processing image 1368
# Processing image 1369
# Processing image 1370
# Processing image 1371
# Processing image 1372
# Processing image 1373
# Processing image 1374
# Warning: Could not read image testset/b87d645ad38f9bc1c03dc90470138d69  -.md. Skipping.
# Processing image 1375
# Processing image 1376
# Processing image 1377
# Processing image 1378
# Processing image 1379
# Processing image 1380
# Processing image 1381
# Processing image 1382
# Processing image 1383
# Processing image 1384
# Processing image 1385
# Processing image 1386
# Processing image 1387
# Processing image 1388
# Processing image 1389
# Processing image 1390
# Processing image 1391
# Processing image 1392
# Processing image 1393
# Processing image 1394
# Processing image 1395
# Processing image 1396
# Processing image 1397
# Processing image 1398
# Processing image 1399
# Processing image 1400
# Processing image 1401
# Processing image 1402
# Processing image 1403
# Processing image 1404
# Processing image 1405
# Processing image 1406
# Processing image 1407
# Processing image 1408
# Processing image 1409
# Warning: No contours found in image after filtering and adaptive thresholding. Skipping.
# Processing image 1410
# Processing image 1411
# Processing image 1412
# Processing image 1413
# Processing image 1414
# Processing image 1415
# Processing image 1416
# Processing image 1417
# Processing image 1418
# Processing image 1419
# Processing image 1420
# Processing image 1421
# Processing image 1422
# Processing image 1423
# Processing image 1424
# Processing image 1425
# Processing image 1426
# Processing image 1427
# Processing image 1428
# Processing image 1429
# Processing image 1430
# Processing image 1431
# Processing image 1432
# Processing image 1433
# Processing image 1434
# Processing image 1435
# Processing image 1436
# Processing image 1437
# Processing image 1438
# Processing image 1439
# Processing image 1440
# Processing image 1441
# Processing image 1442
# Processing image 1443
# Processing image 1444
# Processing image 1445
# Processing image 1446
# Processing image 1447
# Processing image 1448
# Processing image 1449
# Processing image 1450
# Processing image 1451
# Processing image 1452
# Processing image 1453
# Processing image 1454
# Processing image 1455
# Processing image 1456
# Processing image 1457
# Processing image 1458
# Processing image 1459
# Processing image 1460
# Processing image 1461
# Processing image 1462
# Processing image 1463
# Processing image 1464
# Processing image 1465
# Processing image 1466
# Processing image 1467
# Processing image 1468
# Processing image 1469
# Processing image 1470
# Processing image 1471
# Processing image 1472
# Processing image 1473
# Processing image 1474
# Processing image 1475
# Processing image 1476
# Processing image 1477
# Processing image 1478
# Processing image 1479
# Processing image 1480
# Processing image 1481
# Processing image 1482
# Processing image 1483
# Processing image 1484
# Processing image 1485
# Processing image 1486
# Processing image 1487
# Processing image 1488
# Processing image 1489
# Processing image 1490
# Processing image 1491
# Processing image 1492
# Processing image 1493
# Processing image 1494
# Processing image 1495
# Processing image 1496
# Processing image 1497
# Processing image 1498
# Processing image 1499
# Processing image 1500
# Processing image 1501
# Processing image 1502
# Processing image 1503
# Processing image 1504
# Processing image 1505
# Processing image 1506
# Processing image 1507
# Processing image 1508
# Processing image 1509
# Processing image 1510
# Processing image 1511
# Processing image 1512
# Processing image 1513
# Processing image 1514
# Processing image 1515
# Processing image 1516
# Processing image 1517
# Processing image 1518
# Processing image 1519
# Processing image 1520
# Processing image 1521
# Processing image 1522
# Processing image 1523
# Processing image 1524
# Processing image 1525
# Processing image 1526
# Processing image 1527
# Processing image 1528
# Processing image 1529
# Processing image 1530
# Processing image 1531
# Processing image 1532
# Processing image 1533
# Processing image 1534
# Processing image 1535
# Processing image 1536
# Processing image 1537
# Processing image 1538
# Processing image 1539
# Warning: No contours found in image after filtering and adaptive thresholding. Skipping.
# Processing image 1540
# Processing image 1541
# Processing image 1542
# Processing image 1543
# Processing image 1544
# Processing image 1545
# Processing image 1546
# Processing image 1547
# Processing image 1548
# Processing image 1549
# Processing image 1550
# Processing image 1551
# Processing image 1552
# Processing image 1553
# Processing image 1554
# Processing image 1555
# Processing image 1556
# Warning: Could not read image testset/9b78ce3efdb35c807607f1d60e070094.HEIC. Skipping.
# Processing image 1557
# Processing image 1558
# Processing image 1559
# Processing image 1560
# Processing image 1561
# Processing image 1562
# Processing image 1563
# Processing image 1564
# Processing image 1565
# Processing image 1566
# Processing image 1567
# Processing image 1568
# Processing image 1569
# Processing image 1570
# Processing image 1571
# Processing image 1572
# Processing image 1573
# Processing image 1574
# Processing image 1575
# Processing image 1576
# Processing image 1577
# Processing image 1578
# Processing image 1579
# Processing image 1580
# Processing image 1581
# Processing image 1582
# Processing image 1583
# Processing image 1584
# Processing image 1585
# Processing image 1586
# Processing image 1587
# Processing image 1588
# Processing image 1589
# Processing image 1590
# Processing image 1591
# Processing image 1592
# Processing image 1593
# Processing image 1594
# Processing image 1595
# Processing image 1596
# Processing image 1597
# Processing image 1598
# Processing image 1599
# Processing image 1600
# Processing image 1601
# Processing image 1602
# Processing image 1603
# Processing image 1604
# Processing image 1605
# Processing image 1606
# Processing image 1607
# Processing image 1608
# Processing image 1609
# Processing image 1610
# Processing image 1611
# Processing image 1612
# Processing image 1613
# Processing image 1614
# Processing image 1615
# Processing image 1616
# Processing image 1617
# Processing image 1618
# Processing image 1619
# Processing image 1620
# Processing image 1621
# Processing image 1622
# Processing image 1623
# Processing image 1624
# Processing image 1625
# Processing image 1626
# Processing image 1627
# Processing image 1628
# Processing image 1629
# Processing image 1630
# Processing image 1631
# Processing image 1632
# Processing image 1633
# Processing image 1634
# Processing image 1635
# Processing image 1636
# Processing image 1637
# Processing image 1638
# Processing image 1639
# Processing image 1640
# Processing image 1641
# Processing image 1642
# Processing image 1643
# Processing image 1644
# Processing image 1645
# Processing image 1646
# Processing image 1647
# Processing image 1648
# Processing image 1649
# Processing image 1650
# Processing image 1651
# Processing image 1652
# Processing image 1653
# Processing image 1654
# Processing image 1655
# Processing image 1656
# Processing image 1657
# Processing image 1658
# Processing image 1659
# Processing image 1660
# Processing image 1661
# Processing image 1662
# Processing image 1663
# Warning: Could not read image testset/fd50b14dd3d3d0a482a4efc55d525298.HEIC. Skipping.
# Processing image 1664
# Processing image 1665
# Processing image 1666
# Processing image 1667
# Processing image 1668
# Processing image 1669
# Processing image 1670
# Processing image 1671
# Processing image 1672
# Processing image 1673
# Processing image 1674
# Processing image 1675
# Processing image 1676
# Processing image 1677
# Processing image 1678
# Processing image 1679
# Processing image 1680
# Processing image 1681
# Processing image 1682
# Processing image 1683
# Processing image 1684
# Processing image 1685
# Processing image 1686
# Processing image 1687
# Processing image 1688
# Processing image 1689
# Processing image 1690
# Processing image 1691
# Processing image 1692
# Processing image 1693
# Processing image 1694
# Processing image 1695
# Processing image 1696
# Processing image 1697
# Processing image 1698
# Processing image 1699
# Processing image 1700
# Processing image 1701
# Processing image 1702
# Processing image 1703
# Warning: Could not read image testset/e978fb00a535e15e0ddec4f50089b8ac  -.HEIC. Skipping.
# Processing image 1704
# Processing image 1705
# Processing image 1706
# Processing image 1707
# Processing image 1708
# Processing image 1709
# Processing image 1710
# Processing image 1711
# Processing image 1712
# Processing image 1713
# Processing image 1714
# Warning: Could not read image testset/dacec8de1e92ae8a22657c3f4b7c6331.HEIC. Skipping.
# Processing image 1715
# Processing image 1716
# Processing image 1717
# Processing image 1718
# Processing image 1719
# Processing image 1720
# Processing image 1721
# Processing image 1722
# Processing image 1723
# Processing image 1724
# Processing image 1725
# Processing image 1726
# Processing image 1727
# Processing image 1728
# Processing image 1729
# Processing image 1730
# Processing image 1731
# Processing image 1732
# Processing image 1733
# Processing image 1734
# Processing image 1735
# Processing image 1736
# Processing image 1737
# Processing image 1738
# Processing image 1739
# Processing image 1740
# Processing image 1741
# Processing image 1742
# Processing image 1743
# Processing image 1744
# Processing image 1745
# Processing image 1746
# Processing image 1747
# Processing image 1748
# Processing image 1749
# Processing image 1750
# Processing image 1751
# Processing image 1752
# Processing image 1753
# Processing image 1754
# Processing image 1755
# Processing image 1756
# Processing image 1757
# Processing image 1758
# Processing image 1759
# Processing image 1760
# Processing image 1761
# Processing image 1762
# Processing image 1763
# Processing image 1764
# Processing image 1765
# Processing image 1766
# Processing image 1767
# Processing image 1768
# Processing image 1769
# Processing image 1770
# Processing image 1771
# Processing image 1772
# Processing image 1773
# Processing image 1774
# Processing image 1775
# Processing image 1776
# Processing image 1777
# Processing image 1778
# Processing image 1779
# Processing image 1780
# Processing image 1781
# Processing image 1782
# Processing image 1783
# Processing image 1784
# Processing image 1785
# Processing image 1786
# Processing image 1787
# Processing image 1788
# Processing image 1789
# Processing image 1790
# Processing image 1791
# Processing image 1792
# Processing image 1793
# Processing image 1794
# Processing image 1795
# Processing image 1796
# Processing image 1797
# Processing image 1798
# Processing image 1799
# Processing image 1800
# Processing image 1801
# Processing image 1802
# Processing image 1803
# Processing image 1804
# Processing image 1805
# Processing image 1806
# Processing image 1807
# Processing image 1808
# Processing image 1809
# Processing image 1810
# Processing image 1811
# Processing image 1812
# Processing image 1813
# Processing image 1814
# Processing image 1815
# Processing image 1816
# Processing image 1817
# Processing image 1818
# Processing image 1819
# Processing image 1820
# Processing image 1821
# Processing image 1822
# Processing image 1823
# Processing image 1824
# Processing image 1825
# Processing image 1826
# Processing image 1827
# Processing image 1828
# Processing image 1829
# Processing image 1830
# Processing image 1831
# Processing image 1832
# Processing image 1833
# Processing image 1834
# Processing image 1835
# Processing image 1836
# Processing image 1837
# Processing image 1838
# Processing image 1839
# Processing image 1840
# Processing image 1841
# Processing image 1842
# Processing image 1843
# Processing image 1844
# Processing image 1845
# Processing image 1846
# Processing image 1847
# Processing image 1848
# Processing image 1849
# Processing image 1850
# Processing image 1851
# Processing image 1852
# Processing image 1853
# Processing image 1854
# Processing image 1855
# Processing image 1856
# Processing image 1857
# Processing image 1858
# Processing image 1859
# Processing image 1860
# Processing image 1861
# Processing image 1862
# Processing image 1863
# Processing image 1864
# Processing image 1865
# Processing image 1866
# Processing image 1867
# Processing image 1868
# Processing image 1869
# Processing image 1870
# Processing image 1871
# Processing image 1872
# Processing image 1873
# Processing image 1874
# Processing image 1875
# Processing image 1876
# Processing image 1877
# Processing image 1878
# Processing image 1879
# Processing image 1880
# Processing image 1881
# Processing image 1882
# Processing image 1883
# Processing image 1884
# Processing image 1885
# Processing image 1886
# Processing image 1887
# Processing image 1888
# Processing image 1889
# Processing image 1890
# Processing image 1891
# Processing image 1892
# Processing image 1893
# Processing image 1894
# Processing image 1895
# Processing image 1896
# Processing image 1897
# Processing image 1898
# Processing image 1899
# Processing image 1900
# Processing image 1901
# Processing image 1902
# Processing image 1903
# Processing image 1904
# Processing image 1905
# Processing image 1906
# Processing image 1907
# Processing image 1908
# Processing image 1909
# Processing image 1910
# Processing image 1911
# Processing image 1912
# Processing image 1913
# Processing image 1914
# Processing image 1915
# Processing image 1916
# Processing image 1917
# Processing image 1918
# Processing image 1919
# Processing image 1920
# Processing image 1921
# Processing image 1922
# Processing image 1923
# Processing image 1924
# Processing image 1925
# Processing image 1926
# Processing image 1927
# Processing image 1928
# Warning: Could not read image testset/f1a32f97a09fd866097f1c483234dbe8  -.md. Skipping.
# Processing image 1929
# Processing image 1930
# Processing image 1931
# Processing image 1932
# Processing image 1933
# Processing image 1934
# Processing image 1935
# Processing image 1936
# Processing image 1937
# Processing image 1938
# Processing image 1939
# Processing image 1940
# Processing image 1941
# Processing image 1942
# Processing image 1943
# Processing image 1944
# Processing image 1945
# Processing image 1946
# Processing image 1947
# Processing image 1948
# Processing image 1949
# Processing image 1950
# Processing image 1951
# Processing image 1952
# Processing image 1953
# Processing image 1954
# Processing image 1955
# Processing image 1956
# Processing image 1957
# Processing image 1958
# Processing image 1959
# Processing image 1960
# Processing image 1961
# Processing image 1962
# Processing image 1963
# Processing image 1964
# Processing image 1965
# Processing image 1966
# Processing image 1967
# Processing image 1968
# Processing image 1969
# Processing image 1970
# Processing image 1971
# Processing image 1972
# Processing image 1973
# Processing image 1974
# Processing image 1975
# Processing image 1976
# Processing image 1977
# Processing image 1978
# Processing image 1979
# Processing image 1980
# Processing image 1981
# Processing image 1982
# Processing image 1983
# Processing image 1984
# Processing image 1985
# Processing image 1986
# Processing image 1987
# Processing image 1988
# Processing image 1989
# Processing image 1990
# Processing image 1991
# Processing image 1992
# Processing image 1993
# Processing image 1994
# Processing image 1995
# Processing image 1996
# Processing image 1997
# Processing image 1998
# Processing image 1999
# Processing image 2000
# Processing image 2001
# Processing image 2002
# Processing image 2003
# Processing image 2004
# Processing image 2005
# Processing image 2006
# Processing image 2007
# Processing image 2008
# Processing image 2009
# Processing image 2010
# Processing image 2011
# Processing image 2012
# Processing image 2013
# Processing image 2014
# Processing image 2015
# Processing image 2016
# Processing image 2017
# Processing image 2018
# Processing image 2019
# Processing image 2020
# Processing image 2021
# Processing image 2022
# Processing image 2023
# Processing image 2024
# Processing image 2025
# Processing image 2026
# Processing image 2027
# Processing image 2028
# Processing image 2029
# Processing image 2030
# Processing image 2031
# Processing image 2032
# Processing image 2033
# Processing image 2034
# Processing image 2035
# Processing image 2036
# Processing image 2037
# Processing image 2038
# Processing image 2039
# Processing image 2040
# Processing image 2041
# Processing image 2042
# Processing image 2043
# Processing image 2044
# Processing image 2045
# Processing image 2046
# Processing image 2047
# Processing image 2048
# Processing image 2049
# Processing image 2050
# Processing image 2051
# Processing image 2052
# Processing image 2053
# Processing image 2054
# Processing image 2055
# Processing image 2056
# Processing image 2057
# Processing image 2058
# Processing image 2059
# Processing image 2060
# Processing image 2061
# Processing image 2062
# Processing image 2063
# Processing image 2064
# Processing image 2065
# Processing image 2066
# Processing image 2067
# Processing image 2068
# Processing image 2069
# Processing image 2070
# Processing image 2071
# Processing image 2072
# Processing image 2073
# Processing image 2074
# Processing image 2075
# Processing image 2076
# Processing image 2077
# Processing image 2078
# Processing image 2079
# Processing image 2080
# Processing image 2081
# Processing image 2082
# Processing image 2083
# Processing image 2084
# Processing image 2085
# Processing image 2086
# Processing image 2087
# Processing image 2088
# Processing image 2089
# Processing image 2090
# Processing image 2091
# Processing image 2092
# Processing image 2093
# Processing image 2094
# Processing image 2095
# Processing image 2096
# Processing image 2097
# Processing image 2098
# Processing image 2099
# Processing image 2100
# Processing image 2101
# Processing image 2102
# Processing image 2103
# Processing image 2104
# Processing image 2105
# Processing image 2106
# Processing image 2107
# ...
# Processing image 9338
# Processing image 9339
# Processing image 9340
# Processing image 9341
# Processing image 9342
# Processing image 9343
# Processing image 9344
# Processing image 9345
# Processing image 9346
# Processing image 9347
# Processing image 9348
# Processing image 9349
# Processing image 9350
# Processing image 9351
# Processing image 9352
# Processing image 9353
# Processing image 9354
# Processing image 9355
# Processing image 9356
# Processing image 9357
# Processing image 9358
# Processing image 9359
# Processing image 9360
# Processing image 9361
# Processing image 9362
# Processing image 9363
# Processing image 9364
# Processing image 9365
# Processing image 9366
# Processing image 9367
# Processing image 9368
# Processing image 9369
# Processing image 9370
# Processing image 9371
# Processing image 9372
# Processing image 9373
# Processing image 9374
# Processing image 9375
# Processing image 9376
# Processing image 9377
# Processing image 9378
# Processing image 9379
# Processing image 9380
# Processing image 9381
# Processing image 9382
# Processing image 9383
# Processing image 9384
# Processing image 9385
# Processing image 9386
# Processing image 9387
# Processing image 9388
# Processing image 9389
# Processing image 9390
# Processing image 9391
# Processing image 9392
# Processing image 9393
# Processing image 9394
# Processing image 9395
# Processing image 9396
# Processing image 9397
# Processing image 9398
# Processing image 9399
# Processing image 9400
# Processing image 9401
# Processing image 9402
# Processing image 9403
# Processing image 9404
# Processing image 9405
# Processing image 9406
# Processing image 9407
# Processing image 9408
# Processing image 9409
# Warning: Could not read image testset/be633c756666b255f89a23ae798d690d  -.HEIC. Skipping.
# Processing image 9410
# Processing image 9411
# Processing image 9412
# Processing image 9413
# Processing image 9414
# Processing image 9415
# Processing image 9416
# Processing image 9417
# Processing image 9418
# Processing image 9419
# Processing image 9420
# Processing image 9421
# Processing image 9422
# Processing image 9423
# Processing image 9424
# Processing image 9425
# Processing image 9426
# Processing image 9427
# Processing image 9428
# Processing image 9429
# Processing image 9430
# Processing image 9431
# Processing image 9432
# Processing image 9433
# Processing image 9434
# Processing image 9435
# Processing image 9436
# Processing image 9437
# Processing image 9438
# Processing image 9439
# Processing image 9440
# Processing image 9441
# Processing image 9442
# Processing image 9443
# Processing image 9444
# Processing image 9445
# Processing image 9446
# Processing image 9447
# Processing image 9448
# Processing image 9449
# Processing image 9450
# Processing image 9451
# Processing image 9452
# Processing image 9453
# Processing image 9454
# Processing image 9455
# Processing image 9456
# Processing image 9457
# Processing image 9458
# Processing image 9459
# Processing image 9460
# Processing image 9461
# Warning: Could not read image testset/70ebf0bec317006017a54d6c9172af45.jpeg. Skipping.
# Processing image 9462
# Processing image 9463
# Processing image 9464
# Processing image 9465
# Processing image 9466
# Processing image 9467
# Processing image 9468
# Processing image 9469
# Processing image 9470
# Processing image 9471
# Processing image 9472
# Processing image 9473
# Processing image 9474
# Processing image 9475
# Processing image 9476
# Processing image 9477
# Processing image 9478
# Processing image 9479
# Processing image 9480
# Processing image 9481
# Processing image 9482
# Processing image 9483
# Processing image 9484
# Processing image 9485
# Processing image 9486
# Processing image 9487
# Processing image 9488
# Processing image 9489
# Processing image 9490
# Processing image 9491
# Processing image 9492
# Processing image 9493
# Processing image 9494
# Processing image 9495
# Processing image 9496
# Processing image 9497
# Processing image 9498
# Processing image 9499
# Processing image 9500
# Processing image 9501
# Processing image 9502
# Processing image 9503
# Processing image 9504
# Processing image 9505
# Processing image 9506
# Processing image 9507
# Processing image 9508
# Processing image 9509
# Processing image 9510
# Processing image 9511
# Processing image 9512
# Processing image 9513
# Processing image 9514
# Processing image 9515
# Processing image 9516
# Processing image 9517
# Processing image 9518
# Processing image 9519
# Processing image 9520
# Processing image 9521
# Warning: Could not read image testset/f335ebd8f31b916c71ddd182bf2f2e40  -.HEIC. Skipping.
# Processing image 9522
# Processing image 9523
# Processing image 9524
# Processing image 9525
# Processing image 9526
# Processing image 9527
# Processing image 9528
# Processing image 9529
# Processing image 9530
# Processing image 9531
# Processing image 9532
# Processing image 9533
# Processing image 9534
# Processing image 9535
# Processing image 9536
# Processing image 9537
# Processing image 9538
# Processing image 9539
# Processing image 9540
# Processing image 9541
# Processing image 9542
# Processing image 9543
# Processing image 9544
# Warning: Could not read image testset/d4b080c6ce4933f1199fad7f75e7d112.jpeg. Skipping.
# Processing image 9545
# Warning: Could not read image testset/d4b5381a27ee385fcb5e5f1896edcc68  -.HEIC. Skipping.
# Processing image 9546
# Processing image 9547
# Processing image 9548
# Processing image 9549
# Processing image 9550
# Processing image 9551
# Processing image 9552
# Processing image 9553
# Processing image 9554
# Processing image 9555
# Processing image 9556
# Processing image 9557
# Processing image 9558
# Processing image 9559
# Processing image 9560
# Processing image 9561
# Warning: Could not read image testset/ffd4f9df7163f55474a0182265c8d810.jpeg. Skipping.
# Processing image 9562
# Processing image 9563
# Processing image 9564
# Processing image 9565
# Processing image 9566
# Processing image 9567
# Processing image 9568
# Processing image 9569
# Processing image 9570
# Processing image 9571
# Processing image 9572
# Processing image 9573
# Processing image 9574
# Processing image 9575
# Processing image 9576
# Processing image 9577
# Processing image 9578
# Processing image 9579
# Processing image 9580
# Processing image 9581
# Processing image 9582
# Processing image 9583
# Processing image 9584
# Processing image 9585
# Warning: Could not read image testset/97397cc0b77329eae661764697469b2e.HEIC. Skipping.
# Processing image 9586
# Processing image 9587
# Warning: Could not read image testset/974719e3b99c40fd0c51c120b7df92c6.HEIC. Skipping.
# Processing image 9588
# Processing image 9589
# Processing image 9590
# Processing image 9591
# Processing image 9592
# Processing image 9593
# Processing image 9594
# Processing image 9595
# Processing image 9596
# Processing image 9597
# Processing image 9598
# Processing image 9599
# Processing image 9600
# Processing image 9601
# Processing image 9602
# Processing image 9603
# Processing image 9604
# Processing image 9605
# Processing image 9606
# Processing image 9607
# Processing image 9608
# Processing image 9609
# Processing image 9610
# Processing image 9611
# Processing image 9612
# Processing image 9613
# Processing image 9614
# Processing image 9615
# Processing image 9616
# Processing image 9617
# Processing image 9618
# Processing image 9619
# Processing image 9620
# Processing image 9621
# Processing image 9622
# Processing image 9623
# Processing image 9624
# Processing image 9625
# Processing image 9626
# Processing image 9627
# Processing image 9628
# Processing image 9629
# Warning: No contours found in image after filtering and adaptive thresholding. Skipping.
# Processing image 9630
# Processing image 9631
# Processing image 9632
# Processing image 9633
# Processing image 9634
# Processing image 9635
# Processing image 9636
# Processing image 9637
# Processing image 9638
# Processing image 9639
# Processing image 9640
# Processing image 9641
# Processing image 9642
# Processing image 9643
# Warning: Could not read image testset/0737c18223e6c8110ff767ee27841569.HEIC. Skipping.
# Processing image 9644
# Processing image 9645
# Processing image 9646
# Processing image 9647
# Processing image 9648
# Processing image 9649
# Processing image 9650
# Processing image 9651
# Processing image 9652
# Processing image 9653
# Processing image 9654
# Processing image 9655
# Processing image 9656
# Processing image 9657
# Processing image 9658
# Processing image 9659
# Processing image 9660
# Processing image 9661
# Processing image 9662
# Processing image 9663
# Processing image 9664
# Processing image 9665
# Processing image 9666
# Processing image 9667
# Processing image 9668
# Processing image 9669
# Processing image 9670
# Processing image 9671
# Processing image 9672
# Processing image 9673
# Processing image 9674
# Processing image 9675
# Processing image 9676
# Processing image 9677
# Processing image 9678
# Processing image 9679
# Processing image 9680
# Processing image 9681
# Processing image 9682
# Processing image 9683
# Processing image 9684
# Processing image 9685
# Processing image 9686
# Processing image 9687
# Processing image 9688
# Processing image 9689
# Processing image 9690
# Processing image 9691
# Processing image 9692
# Processing image 9693
# Processing image 9694
# Processing image 9695
# Processing image 9696
# Processing image 9697
# Processing image 9698
# Processing image 9699
# Processing image 9700
# Processing image 9701
# Processing image 9702
# Processing image 9703
# Processing image 9704
# Processing image 9705
# Processing image 9706
# Processing image 9707
# Processing image 9708
# Processing image 9709
# Processing image 9710
# Processing image 9711
# Processing image 9712
# Processing image 9713
# Processing image 9714
# Processing image 9715
# Processing image 9716
# Processing image 9717
# Processing image 9718
# Processing image 9719
# Processing image 9720
# Processing image 9721
# Processing image 9722
# Processing image 9723
# Processing image 9724
# Processing image 9725
# Processing image 9726
# Processing image 9727
# Processing image 9728
# Processing image 9729
# Processing image 9730
# Processing image 9731
# Processing image 9732
# Processing image 9733
# Processing image 9734
# Processing image 9735
# Processing image 9736
# Processing image 9737
# Processing image 9738
# Processing image 9739
# Processing image 9740
# Processing image 9741
# Processing image 9742
# Processing image 9743
# Processing image 9744
# Processing image 9745
# Processing image 9746
# Processing image 9747
# Processing image 9748
# Processing image 9749
# Processing image 9750
# Processing image 9751
# Processing image 9752
# Processing image 9753
# Processing image 9754
# Processing image 9755
# Processing image 9756
# Processing image 9757
# Processing image 9758
# Processing image 9759
# Processing image 9760
# Processing image 9761
# Processing image 9762
# Processing image 9763
# Processing image 9764
# Processing image 9765
# Processing image 9766
# Processing image 9767
# Processing image 9768
# Processing image 9769
# Processing image 9770
# Processing image 9771
# Processing image 9772
# Processing image 9773
# Processing image 9774
# Warning: Could not read image testset/78f788851a15c5927a7d079cece219a3.HEIC. Skipping.
# Processing image 9775
# Processing image 9776
# Processing image 9777
# Processing image 9778
# Processing image 9779
# Processing image 9780
# Processing image 9781
# Processing image 9782
# Processing image 9783
# Processing image 9784
# Processing image 9785
# Processing image 9786
# Processing image 9787
# Processing image 9788
# Processing image 9789
# Processing image 9790
# Processing image 9791
# Processing image 9792
# Processing image 9793
# Processing image 9794
# Processing image 9795
# Processing image 9796
# Processing image 9797
# Processing image 9798
# Processing image 9799
# Processing image 9800
# Processing image 9801
# Processing image 9802
# Processing image 9803
# Processing image 9804
# Processing image 9805
# Processing image 9806
# Processing image 9807
# Processing image 9808
# Processing image 9809
# Processing image 9810
# Processing image 9811
# Processing image 9812
# Processing image 9813
# Processing image 9814
# Processing image 9815
# Processing image 9816
# Processing image 9817
# Processing image 9818
# Processing image 9819
# Processing image 9820
# Processing image 9821
# Processing image 9822
# Processing image 9823
# Processing image 9824
# Processing image 9825
# Processing image 9826
# Processing image 9827
# Processing image 9828
# Processing image 9829
# Processing image 9830
# Processing image 9831
# Processing image 9832
# Processing image 9833
# Processing image 9834
# Processing image 9835
# Processing image 9836
# Processing image 9837
# Processing image 9838
# Processing image 9839
# Processing image 9840
# Processing image 9841
# Processing image 9842
# Processing image 9843
# Processing image 9844
# Processing image 9845
# Processing image 9846
# Processing image 9847
# Processing image 9848
# Processing image 9849
# Processing image 9850
# Processing image 9851
# Processing image 9852
# Processing image 9853
# Warning: Could not read image testset/3bce47afe5382ad9e32e1a007c623fea.HEIC. Skipping.
# Processing image 9854
# Processing image 9855
# Processing image 9856
# Warning: Could not read image testset/3bda949d7af8d430cd8b819e2cf70ce5.HEIC. Skipping.
# Processing image 9857
# Processing image 9858
# Processing image 9859
# Processing image 9860
# Processing image 9861
# Processing image 9862
# Processing image 9863
# Processing image 9864
# Processing image 9865
# Processing image 9866
# Processing image 9867
# Processing image 9868
# Processing image 9869
# Processing image 9870
# Processing image 9871
# Processing image 9872
# Processing image 9873
# Processing image 9874
# Processing image 9875
# Processing image 9876
# Processing image 9877
# Processing image 9878
# Warning: Could not read image testset/9e1f3378e66e8cd4c1f795d8e642fc60.HEIC. Skipping.
# Processing image 9879
# Processing image 9880
# Processing image 9881
# Processing image 9882
# Processing image 9883
# Processing image 9884
# Processing image 9885
# Processing image 9886
# Processing image 9887
# Processing image 9888
# Processing image 9889
# Processing image 9890
# Processing image 9891
# Processing image 9892
# Processing image 9893
# Processing image 9894
# Processing image 9895
# Processing image 9896
# Processing image 9897
# Processing image 9898
# Processing image 9899
# Processing image 9900
# Processing image 9901
# Processing image 9902
# Processing image 9903
# Processing image 9904
# Processing image 9905
# Processing image 9906
# Processing image 9907
# Processing image 9908
# Processing image 9909
# Processing image 9910
# Processing image 9911
# Processing image 9912
# Processing image 9913
# Processing image 9914
# Processing image 9915
# Processing image 9916
# Processing image 9917
# Processing image 9918
# Processing image 9919
# Processing image 9920
# Processing image 9921
# Processing image 9922
# Processing image 9923
# Processing image 9924
# Processing image 9925
# Processing image 9926
# Processing image 9927
# Processing image 9928
# Processing image 9929
# Processing image 9930
# Processing image 9931
# Processing image 9932
# Processing image 9933
# Processing image 9934
# Processing image 9935
# Processing image 9936
# Processing image 9937
# Processing image 9938
# Processing image 9939
# Processing image 9940
# Processing image 9941
# Processing image 9942
# Warning: Could not read image testset/f204b661b1663aa3d3f11b458bdebfbd.HEIC. Skipping.
# Processing image 9943
# Processing image 9944
# Processing image 9945
# Processing image 9946
# Processing image 9947
# Processing image 9948
# Processing image 9949
# Processing image 9950
# Processing image 9951
# Processing image 9952
# Processing image 9953
# Processing image 9954
# Processing image 9955
# Processing image 9956
# Processing image 9957
# Processing image 9958
# Processing image 9959
# Processing image 9960
# Processing image 9961
# Processing image 9962
# Processing image 9963
# Processing image 9964
# Processing image 9965
# Processing image 9966
# Processing image 9967
# Processing image 9968
# Processing image 9969
# Warning: Could not read image testset/fc972fff77ea8b755bb7de37f7c94046.HEIC. Skipping.
# Processing image 9970
# Processing image 9971
# Processing image 9972
# Processing image 9973
# Processing image 9974
# Processing image 9975
# Processing image 9976
# Processing image 9977
# Processing image 9978
# Processing image 9979
# Processing image 9980
# Processing image 9981
# Processing image 9982
# Processing image 9983
# Processing image 9984
# Processing image 9985
# Processing image 9986
# Processing image 9987
# Processing image 9988
# Processing image 9989
# Processing image 9990
# Processing image 9991
# Processing image 9992
# Processing image 9993
# Processing image 9994
# Processing image 9995
# Processing image 9996
# Processing image 9997
# Processing image 9998
# Data successfully written to 'resnet34.csv'
